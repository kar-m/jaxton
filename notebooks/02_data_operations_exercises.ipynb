# %% [markdown]
# <center>
#     <h1>JaxTon</h1>
#     <i>💯 JAX exercises</i>
#     <br>
#     <br>
#     <a href='https://github.com/vopani/jaxton/blob/master/LICENSE'>
#         <img src='https://img.shields.io/badge/license-Apache%202.0-blue.svg?logo=apache'>
#     </a>
#     <a href='https://github.com/vopani/jaxton'>
#         <img src='https://img.shields.io/github/stars/vopani/jaxton?color=yellowgreen&logo=github'>
#     </a>
#     <a href='https://twitter.com/vopani'>
#         <img src='https://img.shields.io/twitter/follow/vopani'>
#     </a>
# </center>

# %% [markdown]
# <center>
#     This is Set 2: Data Operations (Exercises 11-20) of <b>JaxTon</b>: <i>💯 JAX exercises</i>
#     <br>
#     You can find all the exercises and solutions on <a href="https://github.com/vopani/jaxton#exercises-">GitHub</a>
# </center>

# %% [markdown]
# **Prerequisites**
#
# * Run the setup cells below before starting the exercises.

# %%
## install or upgrade jax
# !python3 -m pip install -U jax
# Out:
# Requirement already satisfied: jax in /Users/karen/jaxton/.venv/lib/python3.11/site-packages (0.10.1)
# Requirement already satisfied: jaxlib<=0.10.1,>=0.10.1 in /Users/karen/jaxton/.venv/lib/python3.11/site-packages (from jax) (0.10.1)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /Users/karen/jaxton/.venv/lib/python3.11/site-packages (from jax) (0.5.4)
# Requirement already satisfied: numpy>=2.0 in /Users/karen/jaxton/.venv/lib/python3.11/site-packages (from jax) (2.4.6)
# Requirement already satisfied: opt_einsum in /Users/karen/jaxton/.venv/lib/python3.11/site-packages (from jax) (3.4.0)
# Requirement already satisfied: scipy>=1.14 in /Users/karen/jaxton/.venv/lib/python3.11/site-packages (from jax) (1.17.1)

# %%
## import packages
import jax
import jax.numpy as jnp

jax.devices()
# Out:
# [CpuDevice(id=0)]

# %% [markdown]
# **Exercise 11: Create a matrix with values [[10, 1, 24], [20, 15, 14]] and assign it to `data`**

# %%
data = jnp.array([[10, 1, 24], [20, 15, 14]])
data
# Out:
# Array([[10,  1, 24],
#        [20, 15, 14]], dtype=int32)

# %% [markdown]
# **Exercise 12: Assign the transpose of `data` to `dataT`**

# %%
dataT = data.T

# %% [markdown]
# **Exercise 13: Assign the element of `data` at index [0, 2] to `value`**

# %%
value = data[0, 2]

# %% [markdown]
# **Exercise 14: Update the value of `data` at index [1, 1] to `100`**

# %%
data = data.at[1, 1].set(100)

# %% [markdown]
# **Exercise 15: Add `41` to the value of `data` at index [0, 0]**

# %%
data = data.at[0, 0].add(41)

# %% [markdown]
# **Exercise 16: Calculate the minimum values over axis=1 and assign it to `mins`**

# %%
mins = data.min(axis=1)
mins
# Out:
# Array([ 1, 14], dtype=int32)

# %% [markdown]
# **Exercise 17: Select the first row of values of `data` and assign it to `data_select`**

# %%
data_select = data[0, :]
data_select
# Out:
# Array([51,  1, 24], dtype=int32)

# %% [markdown]
# **Exercise 18: Append the row `data_select` to `data`**

# %%
data = jnp.concat([data, data_select[None, :]], axis=0)
data
# Out:
# Array([[ 51,   1,  24],
#        [ 20, 100,  14],
#        [ 51,   1,  24],
#        [ 51,   1,  24]], dtype=int32)

# %% [markdown]
# **Exercise 19: Multiply the matrices `data` and `dataT` and assign it to `data_prod`**

# %%
data_prod = data @ dataT

# %% [markdown]
# **Exercise 20: Convert the dtype of `data_prod` to `float32`**

# %%
data_prod = data_prod.astype(jnp.float32)

# %% [markdown]
# <center>
#     This completes Set 2: Data Operations (Exercises 11-20) of <b>JaxTon</b>: <i>💯 JAX exercises</i>
#     <br>
#     You can find all the exercises and solutions on <a href="https://github.com/vopani/jaxton#exercises-">GitHub</a>
# </center>
